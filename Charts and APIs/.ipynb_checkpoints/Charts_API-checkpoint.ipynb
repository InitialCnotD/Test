# %%
import requests
import json
import pandas as pd
import matplotlib.pyplot as plt 
response_API = requests.get('https://api.covid19api.com/live/country/singapore')
print(response_API.status_code)
# Out:
# 200

# %%
data = response_API.text
df = pd.read_json(data)
df
# Out:
#                                        ID    Country CountryCode Province  \
# 0    4599b14a-4c64-450f-90bd-271b7c27bb53  Singapore          SG
# 1    5fc8058a-3d94-44bb-b9ca-42b5cbd671e8  Singapore          SG
# 2    1dfe7e1d-c461-4ff0-9752-c9227aefe666  Singapore          SG
# 3    8880a501-069a-4a17-b1b9-94b4f4970e2b  Singapore          SG
# 4    f0b30cfa-fc29-4b4c-9514-89fd3474a357  Singapore          SG
# ..                                    ...        ...         ...      ...
# 150  a00fffc7-da65-4e03-98d6-7134c3da8913  Singapore          SG
# 151  7049d43f-d81f-4b2c-a243-6543664f06da  Singapore          SG
# 152  f98bc4a4-b058-4ca5-9052-663b8ae94918  Singapore          SG
# 153  92d3c23d-59b5-4fb9-ad26-9bf9e9c7e1ce  Singapore          SG
# 154  3ea0aeb9-701f-43d4-8f6f-c70dbce4254c  Singapore          SG
#
#     City CityCode   Lat     Lon  Confirmed  Deaths  Recovered  Active  \
# 0                  1.35  103.82      62493      35      62140     318
# ...

# %%
plt.plot(df['Date'], df['Confirmed'], color='k', label='Confirmed')
plt.title('Confirmed Case in Singapore')
plt.legend()
plt.show()

# %%
plt.plot(df['Date'], df['Deaths'], color='r', label='Deaths')
plt.title('Death Case in Singapore')
plt.legend()
plt.show()

# %%
plt.plot(df['Date'], df['Recovered'], color='b', label='Recovered')
plt.plot(df['Date'], df['Active'], color='g', label='Active')
plt.title('Recovered and Active Case in Singapore')
plt.legend()
plt.show()
